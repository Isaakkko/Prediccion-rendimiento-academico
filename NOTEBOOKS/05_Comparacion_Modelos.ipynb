# %% [markdown]
# Comparacion de modelos

# %% [markdown]
# Modelo de regresion

# %%
import pandas as pd
# https://pandas.pydata.org/docs/user_guide/index.html#user-guide

# %%
comparacion = pd.DataFrame({
    'Modelo':['ANN Base','ANN + Feature Engineering'],
    'EVS': [0.813,0.826],
    'MAE': [1.15,1.12],
    'RMSE': [1.74,1.70],
    'R2' : [0.81,0.82]
})

comparacion
# Out:
#                       Modelo    EVS   MAE  RMSE    R2
# 0                   ANN Base  0.813  1.15  1.74  0.81
# 1  ANN + Feature Engineering  0.826  1.12  1.70  0.82

# %%
comparacion_regresion.plot(
    x='Modelo',
    y=['MAE','RMSE'],
    kind='bar'
)
# Out:
# <Axes: xlabel='Modelo'>

# %%
comparacion_regresion.plot(
    x='Modelo',
    y='R2',
    kind='bar'
)
# Out:
# <Axes: xlabel='Modelo'>

# %% [markdown]
# El uso de variables derivadas del feature engineering permite mejorar el rendimiento del modelo de regresión
# Se observa disminución del MAE, RMSE y un aumento del R2 entonces con esto sabemos que las variables aportan informacion que es útil para el modelo de rendimiento académico

# %%
comparacion_clasificacion = pd.DataFrame({
    'Modelo':['ANN Base','ANN + Feature Engineering'],
    'Accuracy':[0.80,0.78],
    'Precision':[0.82,0.77],
    'Recall':[0.80,0.78],
    'F1 Score':[0.81,0.76]
})

comparacion_clasificacion
# Out:
#                       Modelo  Accuracy  Precision  Recall  F1 Score
# 0                   ANN Base      0.80       0.82    0.80      0.81
# 1  ANN + Feature Engineering      0.78       0.77    0.78      0.76

# %%
comparacion_clasificacion.plot(
    x='Modelo',
    y=['Accuracy','F1 Score'],
    kind='bar'
)
# Out:
# <Axes: xlabel='Modelo'>

# %%
comparacion_clasificacion.plot(
    x='Modelo',
    y=['Precision','Recall'],
    kind='bar'
)
# Out:
# <Axes: xlabel='Modelo'>

# %% [markdown]
# El uso de variables derivadas en el modelo de clasificación no mejoró el rendimiento del modelo
# Bajó el accuracy, precision, recall y F1 score en comparacion al modelo base
# Esto nos indica que las nuevas variables no aportan informacion de valor al modelo entonces tiene mejor rendimiento el modelo de clasificacion base.

# %% [markdown]
# El feature engineering tuvo efectos diferentes en los modelos
# En el modelo de regresión permitió mejorar las metricas de desempeño y en el modelo de clasificacion multiclase las variables derivadas reducen las metricas de desempeño.
# Es recomendable alimentar con más historicos para ver el comportamiento de los modelos y ver si siguen mejorando.
